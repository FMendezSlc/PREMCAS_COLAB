# %% [markdown]
# #Clustering T1 metrics

# %%
import pandas as pd
import scipy.cluster as clust
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import calinski_harabasz_score as CHS
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import networkx as nx
from networkx.algorithms import clique
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn import metrics

# %%
raw_metrics = pd.read_csv('/Users/labc02/Documents/PREEMACS/data_base_FEL_210520 copy.csv')

# %%
raw_metrics.dropna(how = 'all', inplace = True)
raw_metrics = raw_metrics.astype({'Class_1' :'int32', 'Class_2':'int32', 'Class_3':'int32'})
raw_metrics
# Out:
#     Unnamed: 0    Site  Class_1  Class_2  Class_3      DICE       cjv  \
# 0          0.0     AMU        2        2        2       NaN  0.437439
# 1          1.0     AMU        2        2        2  0.970552  0.435989
# 2          2.0     AMU        3        3        3  0.968544  0.427700
# 3          3.0     AMU        3        3        3  0.966112  0.450975
# 4          4.0    ECNU        3        3        3  0.979284  0.408896
# ..         ...     ...      ...      ...      ...       ...       ...
# 64        64.0  NEWCAS        3        3        3       NaN  0.321902
# 65        65.0  NEWCAS        3        3        3       NaN  0.360775
# 66        66.0  NEWCAS        3        3        3       NaN  0.332643
# 67        67.0   UMINN        3        3        3       NaN  0.481559
# 68        68.0   UMINN        3        3        3       NaN  0.411882
#
#          cnr       efc  fwhm_avg  ...  summary_wm_mean  summary_wm_median  \
# 0   3.112410  0.874622  4.175593  ...      1004.170715        1000.151001
# 1   3.129647  0.823220  5.194107  ...      1008.314941        1000.044495
# 2   3.171547  0.763682  4.421860  ...      1002.342102        1000.118774
# 3   2.913519  0.892556  4.285407  ...      1010.344543        1000.088013
# 4   3.447340  0.755326  5.767960  ...      1005.318970        1000.067749
# ..       ...       ...       ...  ...              ...                ...
# 64  4.144898  0.774400  5.423660  ...      1005.004272         999.994995
# 65  3.549498  0.740198  4.928740  ...      1009.156677         999.994080
# 66  3.899484  0.766744  5.452460  ...      1003.077820        1000.003113
# 67  2.826962  0.766349  4.203707  ...      1008.242371        1000.014648
# 68  3.156497  0.728735  4.272500  ...      1007.477173        1000.054626
#
#     summary_wm_n  summary_wm_p05  summary_wm_p95  summary_wm_stdv  \
# 0        86284.0      874.981107     1151.646039        85.054184
# 1       136961.0      911.091309     1131.242798        69.707794
# 2        51588.0      880.193790     1133.884430        79.106232
# 3        92034.0      875.890634     1184.610614        95.618935
# 4       105402.0      884.939569     1147.680914        81.727478
# ..           ...             ...             ...              ...
# 64      131360.0      883.686740     1143.270868        78.455673
# 65      128124.0      860.342837     1189.971240       101.603935
# 66      120889.0      880.123438     1136.343677        78.442223
# 67      145238.0      919.863861     1126.376489        63.531052
# 68      110211.0      919.773193     1120.938477        62.402958
#
#     tpm_overlap_csf  tpm_overlap_gm  tpm_overlap_wm    wm2max
# 0          0.238507        0.487515        0.502867  0.550889
# 1          0.179574        0.469644        0.510231  0.708890
# 2          0.228725        0.518993        0.521569  0.439233
# 3          0.273287        0.487455        0.522509  0.579871
# 4          0.153531        0.484158        0.469426  0.756391
# ..              ...             ...             ...       ...
# 64         0.086979        0.430423        0.442920  0.698620
# 65         0.096772        0.403082        0.419329  0.704195
# 66         0.097180        0.461324        0.481742  0.600427
# 67         0.166894        0.366028        0.465996  0.714328
# 68         0.070651        0.313065        0.336887  0.538078
#
# [69 rows x 64 columns]

# %%
# DO NOT RUN AGAIN
# This creates a shitload of figures
fig_num = 0
for ii in range(3, 31, 4):
    for jj in range(31, 62, 4):
        g = sns.PairGrid(std_df, hue= 'Class', x_vars = std_df.columns[ii:ii+4], y_vars = std_df.columns[jj:jj+4])
        g.map(plt.scatter)
        g.add_legend()
        g.savefig(f'/Users/labc02/Documents/PREEMACS/Std_VarGrid{fig_num}')
        plt.close()
        fig_num += 1

# %%
# Data standarization
std_df = raw_metrics.copy()
wk_slice = raw_metrics.iloc[:,6:].copy()
wk_slice = (wk_slice - wk_slice.mean()) / wk_slice.std()
std_df.iloc[:,6:] = wk_slice
std_df
# Out:
#     Unnamed: 0    Site  Class_1  Class_2  Class_3      DICE       cjv  \
# 0          0.0     AMU        2        2        2       NaN  0.509762
# 1          1.0     AMU        2        2        2  0.970552  0.486392
# 2          2.0     AMU        3        3        3  0.968544  0.352806
# 3          3.0     AMU        3        3        3  0.966112  0.727916
# 4          4.0    ECNU        3        3        3  0.979284  0.049726
# ..         ...     ...      ...      ...      ...       ...       ...
# 64        64.0  NEWCAS        3        3        3       NaN -1.352342
# 65        65.0  NEWCAS        3        3        3       NaN -0.725840
# 66        66.0  NEWCAS        3        3        3       NaN -1.179234
# 67        67.0   UMINN        3        3        3       NaN  1.220846
# 68        68.0   UMINN        3        3        3       NaN  0.097859
#
#          cnr       efc  fwhm_avg  ...  summary_wm_mean  summary_wm_median  \
# 0  -0.474520  1.764166 -0.660006  ...        -0.406823           1.055715
# 1  -0.446643  0.870210  0.952956  ...         0.018858           0.091482
# 2  -0.378879 -0.165243 -0.270008  ...        -0.594653           0.763954
# 3  -0.796177  2.076069 -0.486101  ...         0.227333           0.485465
# 4   0.067148 -0.310566  1.861735  ...        -0.288878           0.302008
# ..       ...       ...       ...  ...              ...                ...
# 64  1.195277  0.021157  1.316486  ...        -0.321203          -0.356657
# 65  0.232364 -0.573678  0.532709  ...         0.105319          -0.364945
# 66  0.798381 -0.112003  1.362095  ...        -0.519082          -0.283163
# 67 -0.936161 -0.118873 -0.615485  ...         0.011404          -0.178733
# 68 -0.403220 -0.773035 -0.506541  ...        -0.067194           0.183201
#
#     summary_wm_n  summary_wm_p05  summary_wm_p95  summary_wm_stdv  \
# 0      -0.541321       -0.053104       -0.164922        -0.114768
# 1       1.369705        0.751995       -0.393582        -0.499741
# 2      -1.849705        0.063116       -0.363977        -0.263976
# 3      -0.324489       -0.032826        0.204513         0.150256
# 4       0.179617        0.168926       -0.209359        -0.198220
# ..           ...             ...             ...              ...
# 64      1.158492        0.140993       -0.258783        -0.280295
# 65      1.036462       -0.379474        0.264590         0.300394
# 66      0.763631        0.061547       -0.336416        -0.280633
# 67      1.681830        0.947584       -0.448119        -0.654689
# 68      0.360964        0.945563       -0.509063        -0.682988
#
#     tpm_overlap_csf  tpm_overlap_gm  tpm_overlap_wm    wm2max
# 0          0.937943        0.506862        0.255433 -0.655791
# 1         -0.154721        0.211481        0.364186  0.638335
# 2          0.756568        1.027116        0.531640 -1.570325
# 3          1.582789        0.505860        0.545531 -0.418415
# 4         -0.637587        0.451371       -0.238459  1.027392
# ..              ...             ...             ...       ...
# 64        -1.871537       -0.436750       -0.629931  0.554212
# 65        -1.689963       -0.888652       -0.978348  0.599878
# 66        -1.682397        0.073967       -0.056559 -0.250044
# 67        -0.389821       -1.501064       -0.289119  0.682872
# 68        -2.174273       -2.376444       -2.195946 -0.760727
#
# [69 rows x 64 columns]

# %%
# Calculate Pairwise Calinsky-Harabaz Score Between All Metrics Pairs
cols = []
ch_score = np.empty((58, 58))
col = 0
for ii in std_df.columns[6:]:
    cols.append(ii)
    row = 0
    for jj in std_df.columns[6:]:
        X_ = pd.concat([std_df[jj], std_df[ii]], axis = 1)
        ch_score[row, col] = np.round(CHS(X_, std_df['Class_3']), 2)
        row +=1
    col += 1

# %%
np.fill_diagonal(ch_score, 0) # set diagonal to zero
CH_df = pd.DataFrame(data = ch_score, index = cols, columns  = cols)

# %%
CHS_figure = plt.figure(figsize = (15,15))
sns.heatmap(CH_df, square = True, cmap = 'Reds')
plt.title('Pairwise Calinski-Harabaz Score of all Metrics \n for Cluster Evaluation based on Class')
# Out:
# Text(0.5, 1.0, 'Pairwise Calinski-Harabaz Score of all Metrics \n for Cluster Evaluation based on Class')

# %%
CHS_figure.savefig('/Users/labc02/Documents/PREEMACS/Std_metrics_Calkinsky_Harabaz_eval_Class_3.png', ppi = 600)

# %%
# Threshold detection by minimizing edge density
p_ch = []
for ii in np.arange(0.0, max(CH_df.max()), 0.01):
    wk_df = CH_df[CH_df > ii].dropna(axis = 0, how = 'all')
    wk_df = wk_df[wk_df > ii].dropna(axis = 1, how = 'all')
    n = wk_df.shape[0]
    max_ed = (n*(n-1))
    wk_sum = wk_df.notnull().sum().sum()
    wk_p = wk_sum / max_ed
    p_ch.append(wk_p)
# Out:
# <ipython-input-72-8ecd0d570f8d>:9: RuntimeWarning: invalid value encountered in double_scalars
#   wk_p = wk_sum / max_ed

# %%
k = k[~np.isnan(k)]

# %%
# Get the values of the vector
k = np.array(p_ch)
chs_vec = np.arange(0.0, max(CH_df.max()), 0.01)
k_min = np.argmin(k[k>0])
thd = chs_vec[k_min] # threshold value
# Out:
# <ipython-input-85-265133296c13>:4: RuntimeWarning: invalid value encountered in greater
#   k_min = np.argmin(k[k>0])

# %%
th_fig = plt.figure(figsize=(7,5))
ax = th_fig.add_subplot()
plt.plot(np.arange(0.0, max(CH_df.max()), 0.01), p_ch)
plt.title('Threshold Definition by Edge Density Minimization')
plt.xlabel('Calinsky-Harabaz Score')
plt.ylabel('Edge Density (K)')
plt.axvline(thd, 0, .5, color = 'r', linestyle = '--')
plt.annotate('threshold', xy = (chs_vec[k_min], .6), xytext = (-5, 15), textcoords = 'offset points', color = 'r', rotation = 90)
plt.minorticks_on()

# %%
th_fig.savefig('/Users/labc02/Documents/PREEMACS/threshold_edge_min_std_metrics.png', ppi = 600)

# %%
sig_int = []
for column in CH_df.columns:
    sum_int = CH_df[CH_df >thd][column].count()
    sig_int.append(sum_int)

# %%
int_df = pd.DataFrame(data = zip(sig_int, CH_df.columns), columns = ['count', 'metric'])
int_df.sort_values(by = 'count', inplace = True, ascending = False)
int_df
# Out:
#     count              metric
# 56     20      tpm_overlap_wm
# 11     19           inu_range
# 55     11      tpm_overlap_gm
# 17      5           snr_total
# 54      5     tpm_overlap_csf
# 18      5              snr_wm
# 26      3   summary_bg_median
# 28      3      summary_bg_p95
# 41      3   summary_gm_median
# 40      3     summary_gm_mean
# 25      3     summary_bg_mean
# 50      3        summary_wm_n
# 15      2             snr_csf
# 44      2      summary_gm_p95
# 16      2              snr_gm
# 43      2      summary_gm_p05
# 9       2             icvs_wm
# 6       2              fwhm_z
# 5       2              fwhm_y
# 3       2            fwhm_avg
# 51      1      summary_wm_p05
# 39      0      summary_gm_mad
# 38      0        summary_gm_k
# 37      0    summary_csf_stdv
# 42      0        summary_gm_n
# 0       0                 cjv
# 45      0     summary_gm_stdv
# 46      0        summary_wm_k
# 47      0      summary_wm_mad
# 48      0     summary_wm_mean
# 35      0     summary_csf_p05
# 49      0   summary_wm_median
# 52      0      summary_wm_p95
# 53      0     summary_wm_stdv
# 36      0     summary_csf_p95
# 29      0     summary_bg_stdv
# 34      0       summary_csf_n
# 33      0  summary_csf_median
# 2       0                 efc
# 4       0              fwhm_x
# 7       0            icvs_csf
# 8       0             icvs_gm
# 10      0             inu_med
# 12      0            rpve_csf
# 13      0             rpve_gm
# 14      0             rpve_wm
# 19      0            snrd_csf
# 20      0             snrd_gm
# 21      0          snrd_total
# 22      0             snrd_wm
# 23      0        summary_bg_k
# 24      0      summary_bg_mad
# 27      0        summary_bg_n
# 1       0                 cnr
# 30      0       summary_csf_k
# 31      0     summary_csf_mad
# 32      0    summary_csf_mean
# 57      0              wm2max

# %%
p_ = []
deg = []
for ii in range(1,max(int_df['count']), 1):
    num = int_df[int_df['count']>ii].shape[0]
    p = num/int_df['count'].shape[0]
    p_.append(p)
    deg.append(ii)

# %%
s, b = np.polyfit(np.log10(deg), np.log10(p_), 1)

# %%
s, b
# Out:
# (-0.8403053153834616, -0.5232081482922002)

# %%
mtr = int_df['count'].values.shape[0]

# %%
inter_fig = plt.figure(figsize = (10, 8))
ax = inter_fig.add_subplot(212)
plt.bar(x = np.arange(0,mtr, 1), height = int_df['count'].values)
plt.xticks(np.arange(0,mtr, 1))
ax.set_xticklabels(int_df['metric'], rotation = 90, fontsize = 8)
plt.xlabel('Metric')
plt.ylabel('Number of Significant Interactions \n (Degree Centrality)')
ax_1 = inter_fig.add_subplot(211)
plt.bar(deg, p_)
plt.xlabel('Degree')
plt.ylabel('Fraction of Nodes (P)')
plt.minorticks_on()
a = plt.axes([.65, .72, .25, .25])
plt.scatter(np.log10(deg), np.log10(p_), s = 4)
plt.plot(np.log10(deg), (s*np.log10(deg)+b), 'r--', alpha = .5)
plt.ylabel('p(k)')
plt.xlabel('log(k)')
plt.tight_layout()
# Out:
# <ipython-input-97-c320c6f1ac42>:18: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
inter_fig.savefig('/Users/labc02/Documents/PREEMACS/Degree_n_cent_std_metrics.png', ppi = 600, bbox_inches='tight')

# %%
CH_g = nx.Graph()
CH_g.add_nodes_from(CH_df.columns)

# %%
for ii in CH_df.columns:
    for jj in CH_df.index:
        if CH_df.loc[ii, jj] > thd:
            CH_g.add_edge(ii, jj, weight = (1/CH_df.loc[ii, jj]))

# %%
nodes = sorted(CH_g.nodes)
sizes = [CH_g.degree[ii]*10 if CH_g.degree[ii]>0 else 5 for ii in nodes]

# %%
pos = nx.spring_layout(CH_g, seed = 25)

# %%
num_nodes = []
clique_idx = []
for ii, jj in enumerate(clique.find_cliques(CH_g)):
    num_nodes.append(len(jj))
    clique_idx.append(ii)

# %%
all_cliques = list(clique.find_cliques(CH_g))
max_clique = all_cliques[np.argmax(np.array(num_nodes))]
max_pos = nx.spring_layout(CH_g.subgraph(max_clique), seed = 102)
max_nodes = sorted(max_clique)
max_sizes = [CH_g.degree[ii]*100 for ii in max_nodes]

# %%
x_values, y_values = zip(*max_pos.values())
x_max = max(x_values)
x_min = min(x_values)
y_max = max(y_values)
y_min = min(y_values)
x_margin = (x_max - x_min) * 0.25
y_margin = (y_max - y_min) * 0.25

# %%
CHg_fig = plt.figure(figsize = (14,5))
ax_1 = CHg_fig.add_subplot(121)
nx.draw_networkx(CH_g, pos = pos, nodelist = nodes, node_size = sizes, node_color = 'firebrick', node_edge = 'k', with_labels = False, edge_color = 'darkgray', ax = ax_1)
ax_1.set_title('All Metrics Graph')
ax_2 = CHg_fig.add_subplot(122)
nx.draw_networkx(CH_g.subgraph(max_clique), pos = max_pos, nodelist = max_nodes, node_size = max_sizes, node_color = 'indianred', edge_color = 'darkgray', font_weight='bold', ax = ax_2)
ax_2.set_title('Maximum Clique')
plt.xlim(x_min - x_margin, x_max + x_margin)
plt.ylim(y_min - y_margin, y_max + y_margin)
plt.tight_layout()

# %%
CHg_fig.savefig('/Users/labc02/Documents/PREEMACS/metrics_graph_std_metrics.png', ppi = 600, bbox_inches='tight')

# %%
den_fig = plt.figure(figsize=(12,4))
ax = plt.subplot(111)
z = clust.hierarchy.linkage(raw_metrics[max_clique], 'ward')
clust.hierarchy.dendrogram(z, ax = ax, labels = raw_metrics['Class_3'].values)
plt.xticks(fontsize = 10, rotation = 'horizontal')
plt.ylabel('Euclidean Distance')
plt.xlabel('Class')
plt.title(' Data Dendrogram')

#den_fig.savefig('C:\\Users\\FELIPE\\Documents\\PREEMACS\\raw_data_dendrogram.png', dpi = 600)
# Out:
# Text(0.5, 1.0, ' Data Dendrogram')

# %%
den_fig.savefig('/Users/labc02/Documents/PREEMACS/dendrogram_only_max_clique_metrics.png')

# %%
pca = PCA(n_components = 3)
pca_fit = pca.fit_transform(std_df[max_clique])
pca_df = pd.DataFrame(data = pca_fit, columns = ['PC1', 'PC2', 'PC3'])

# %%
colors = []
for ii in std_df['Class_3']:
    if ii == 1:
        colors.append('C0')
    elif ii == 2:
        colors.append('C1')
    elif ii == 3:
        colors.append('C2')
    elif ii == 4:
        colors.append('C3')

# %%
raw_pca = plt.figure(figsize=(14,6))
ax_3 = raw_pca.add_subplot(121, projection='3d')
ax_3.scatter(pca_df['PC1'], pca_df['PC3'], pca_df['PC2'], color = colors)
ax_2  = raw_pca.add_subplot(122)
ax_2.scatter(pca_df['PC1'], pca_df['PC2'], color = colors)
raw_pca.suptitle('Scaled Data PCA')
# Out:
# Text(0.5, 0.98, 'Scaled Data PCA')

# %%
raw_pca.savefig('/Users/labc02/Documents/PREEMACS/PCA_max_clique_std_metrics.png', dpi = 600)

# %%
X_train, x_test, Y_train, y_test = train_test_split(std_df[max_clique], std_df['Class_3'], test_size = 0.2, random_state = 100)

# %%
sv_clf = svm.SVC(kernel = 'rbf')

# %%
sv_clf.fit(X_train, Y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
y_pred =sv_clf.predict(x_test)

# %%
metrics.accuracy_score(y_test, y_pred)
#metrics.precision_score(y_test, y_pred)
#metrics.recall_score(y_test, y_pred)
# Out:
# 1.0
